# %% [markdown]
# # K NN Regression
# ##### its simple work like average sum of points/ no of points

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Salary.csv")

# %%
data.head(3)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
sns.pairplot(data=data)
plt.show()

# %%
sns.boxplot(x="Salary",data=data)
plt.show()

# %%
X=data.iloc[:,:-1]
Y=data["Salary"]

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()
sc.fit(X)
X=pd.DataFrame(sc.transform(X),columns=X.columns)

# %%
X
# Out:
#     YearsExperience       Age
# 0         -1.510053 -1.225076
# 1         -1.438373 -1.126544
# 2         -1.366693 -1.087131
# 3         -1.187494 -1.028012
# 4         -1.115814 -0.988600
# 5         -0.864935 -0.830949
# 6         -0.829096 -0.830949
# 7         -0.757416 -0.771830
# 8         -0.757416 -0.771830
# 9         -0.578216 -0.712712
# 10        -0.506537 -0.653593
# 11        -0.470697 -0.633886
# 12        -0.470697 -0.633886
# 13        -0.434857 -0.633886
# 14        -0.291498 -0.436823
# 15        -0.148138 -0.436823
# 16        -0.076458 -0.239760
# 17        -0.004779 -0.042697
# 18         0.210261  0.154366
# 19         0.246100  0.351429
# 20         0.532819  0.548492
# 21         0.640339  0.548492
# 22         0.927058  0.745555
# 23         1.034577  0.942618
# 24         1.213777  1.139682
# 25         1.321296  1.336745
# 26         1.500496  1.533808
# 27         1.536336  1.730871
# 28         1.787215  1.927934
# 29         1.858894  2.124997

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=10)

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
knn= KNeighborsRegressor(n_neighbors=3)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
knn.score(X_test, Y_test)*100
# Out:
# 97.39142499704374

# %%
knn.score(X_train,Y_train)*100
# Out:
# 97.1875911680297

# %%
for i in range(1,20):
    knn1=KNeighborsRegressor(n_neighbors=i)
    knn1.fit(X_train,Y_train)
    print(i, knn1.score(X_test,Y_test)*100, knn1.score(X_train,Y_train)*100)
# Out:
# 1 93.39199493843671 99.9922560655717
# 2 95.17430412028514 97.55995233020668
# 3 97.39142499704374 97.1875911680297
# 4 94.80897380156007 95.97180618396291
# 5 92.50089226590515 96.32056042844376
# 6 90.68155347419189 95.41684028917676
# 7 89.27057099871489 93.9330300244577
# 8 88.58847599420268 93.12077070070825
# 9 87.03522392353051 91.9919384208612
# 10 86.81599894527807 89.86491594705952
# 11 85.08088718602404 87.74627889998617
# 12 83.35255575536286 85.15258598726342
# 13 80.16290822308065 81.0894304897532
# 14 74.86515236500809 77.00267377369846
# 15 68.45435252351197 72.87964341935093
# 16 59.800397143772976 66.33135800425241
# 17 48.7374180753422 60.08480068141693
# 18 37.99956199007174 53.20474990945885
# 19 27.052263411356968 46.17994008155677

# %%
knn.predict([[-1.510053,-1.225076]])
# Out:
# C:\Users\Utkarsha\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsRegressor was fitted with feature names
#   warnings.warn(
# array([41813.])

# %%
X,Y
# Out:
# (    YearsExperience       Age
#  0         -1.510053 -1.225076
#  1         -1.438373 -1.126544
#  2         -1.366693 -1.087131
#  3         -1.187494 -1.028012
#  4         -1.115814 -0.988600
#  5         -0.864935 -0.830949
#  6         -0.829096 -0.830949
#  7         -0.757416 -0.771830
#  8         -0.757416 -0.771830
#  9         -0.578216 -0.712712
#  10        -0.506537 -0.653593
#  11        -0.470697 -0.633886
#  12        -0.470697 -0.633886
#  13        -0.434857 -0.633886
#  14        -0.291498 -0.436823
#  15        -0.148138 -0.436823
#  16        -0.076458 -0.239760
#  17        -0.004779 -0.042697
#  18         0.210261  0.154366
#  19         0.246100  0.351429
#  20         0.532819  0.548492
#  21         0.640339  0.548492
#  22         0.927058  0.745555
#  23         1.034577  0.942618
#  24         1.213777  1.139682
#  25         1.321296  1.336745
#  26         1.500496  1.533808
#  27         1.536336  1.730871
#  28         1.787215  1.927934
# ...
