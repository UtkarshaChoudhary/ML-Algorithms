# %%
#SingleInput single output

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Socialnetworkads.csv")

# %%
data.drop(columns=["EstimatedSalary"],inplace=True)

# %%
data.head(3)
# Out:
#    Age  Purchased
# 0   19          0
# 1   35          0
# 2   26          0

# %%
data.isnull().sum()
# Out:
# Age          0
# Purchased    0
# dtype: int64

# %%
plt.figure(figsize=(4,3))
sns.scatterplot(x="Age", y="Purchased",data=data)
plt.show()

# %%
X=data[["Age"]]
Y=data["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr= LogisticRegression()
lr.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
lr.score(X_test,Y_test)*100
# Out:
# 91.25

# %%
lr.predict([[30]])
# Out:
# C:\Users\Utkarsha\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="Age", y="Purchased",data=data)
sns.lineplot(x="Age", y=lr.predict(X),data=data,c="red")
plt.show()
