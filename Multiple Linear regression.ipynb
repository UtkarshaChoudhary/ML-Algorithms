# %% [markdown]
# ### Multiple regression on Salary dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("Salary.csv")

# %%
data.head(5)
# Out:
#    YearsExperience   Age  Salary
# 0              1.1  21.0   39343
# 1              1.3  21.5   46205
# 2              1.5  21.7   37731
# 3              2.0  22.0   43525
# 4              2.2  22.2   39891

# %%
data.shape
# Out:
# (30, 3)

# %%
data.isnull().sum()
# Out:
# YearsExperience    0
# Age                0
# Salary             0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.pairplot(data=data)
plt.show()

# %%
sns.heatmap(data=data.corr(),annot=True)
plt.show()

# %%
X=data.iloc[:,:-1]
Y=data["Salary"]

# %%
X.ndim
# Out:
# 2

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=42 )

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test,Y_test)*100
# Out:
# 88.52101657216537

# %%
lr.coef_
# Out:
# array([4882.14850701, 2567.51865301])

# %%
lr.intercept_
# Out:
# -20612.69192148534

# %%
# Y=m1x1+m2x2+C algorithms LR
#Y_pred= 4882.14850701 * AGE + 2567.51865301* Experience + (-20612.69192148534)

# %%
lr.predict(X_test)
# Out:
# array([118686.60525402,  67497.80208802, 101581.52273219,  74585.69879684,
#         54833.367916  ,  58044.6977654 ])
