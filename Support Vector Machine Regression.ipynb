# %% [raw]
# SVR is  regression technique that uses SVM for modeling & predicting continuous outcomes

# %% [raw]
# SVM regression = distance between two outer decision boundry  which is distance is manimum and create a hyperplane which is pass through the average of boundry

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("placement.csv")

# %%
data.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25

# %%
data.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="package",data=data)
plt.show()

# %%
X=data[["cgpa"]]
Y=data["package"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train,Y_test= train_test_split(X,Y,test_size=0.2,random_state=42)

# %%
from sklearn.svm import SVR

# %%
#kernels= 'linear', 'poly', 'rbf', 'sigmoid', 'precomputed'

# %%
svr= SVR(kernel='linear')
svr.fit(X_train,Y_train)
# Out:
# SVR(kernel='linear')

# %%
svr.score(X_test,Y_test)*100
# Out:
# 77.06668029575103

# %%
svr.score(X_train,Y_train)*100
# Out:
# 77.45351616879739

# %%
# we need to show prediction line 
sns.scatterplot(x="cgpa", y="package",data=data)
plt.scatter(data["cgpa"],svr.predict(X),color="red")
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
pf= PolynomialFeatures(degree=2)
pf.fit(X)
X=pd.DataFrame(pf.transform(X))

# %%
X.shape
# Out:
# (200, 3)

# %%
svr1= SVR(kernel='linear')
svr1.fit(X_train,Y_train)
# Out:
# SVR(kernel='linear')

# %%
svr1.score(X_test,Y_test)*100
# Out:
# 77.06668029575103

# %%
svr1.predict([[5.12]])
# Out:
# C:\Users\Utkarsha\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVR was fitted with feature names
#   warnings.warn(
# array([1.8811548])

# %%
data.head(3)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
