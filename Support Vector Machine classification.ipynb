# %% [raw]
# It is also working on linear/regression and non linear/classification
# its a supervised learning algorithms
# first find SVM classification = distance between two in
# ner decision boundry  which is distance is maximum
# we don't want data point in hyperplane

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
from mlxtend.plotting import plot_decision_regions

# %%
data=pd.read_csv("placed.csv")
data.head(3)
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0

# %%
data.isnull().sum()
# Out:
# cgpa         0
# iq           0
# placement    0
# dtype: int64

# %%
plt.figure(figsize=(5,3))
sns.scatterplot(x="cgpa", y="iq",data=data,hue="placement")
plt.show()

# %%
X=data.iloc[:,:-1]
Y=data["placement"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=42)

# %%
from sklearn.svm import SVC

# %%
svc= SVC(kernel='linear')
svc.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
svc.score(X_test,Y_test)*100
# Out:
# 95.0

# %%
svc.score(X_train,Y_train)*100
# Out:
# 91.25

# %%
plot_decision_regions(X.to_numpy(),Y.to_numpy(), clf=svc)
plt.show()
# Out:
# C:\Users\Utkarsha\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
svc.predict([[5.9,106]])
# Out:
# C:\Users\Utkarsha\AppData\Roaming\Python\Python312\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([0])

# %%
data.head(3)
# Out:
#    cgpa   iq  placement
# 0   6.8  123          1
# 1   5.9  106          0
# 2   5.3  121          0
